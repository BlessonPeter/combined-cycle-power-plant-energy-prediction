# %% [markdown]
# # data load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Copy of energy_production (1).csv', sep=';')
df
data = df.copy()
data
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
df.describe()
# Out:
#        temperature  exhaust_vacuum  amb_pressure   r_humidity  \
# count  9568.000000     9568.000000   9568.000000  9568.000000
# mean     19.651231       54.305804   1013.259078    73.308978
# std       7.452473       12.707893      5.938784    14.600269
# min       1.810000       25.360000    992.890000    25.560000
# 25%      13.510000       41.740000   1009.100000    63.327500
# 50%      20.345000       52.080000   1012.940000    74.975000
# 75%      25.720000       66.540000   1017.260000    84.830000
# max      37.110000       81.560000   1033.300000   100.160000
#
#        energy_production
# count        9568.000000
# mean          454.365009
# std            17.066995
# min           420.260000
# 25%           439.750000
# 50%           451.550000
# 75%           468.430000
# max           495.760000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature        9568 non-null   float64
#  1   exhaust_vacuum     9568 non-null   float64
#  2   amb_pressure       9568 non-null   float64
#  3   r_humidity         9568 non-null   float64
#  4   energy_production  9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %% [markdown]
# ## Insights-
# All the data is in float datatype
#
# There is no null value present

# %%
# correlation coefficeient
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## checking duplicates

# %%
df.duplicated().sum()
# Out:
# 41

# %%
df[df.duplicated()]
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 2066        10.72           41.17       1019.68       60.71             479.21
# 2780        28.41           75.60       1018.48       56.07             440.28
# 3333        24.79           75.60       1017.07       68.23             440.05
# 3467         7.64           41.17       1020.01       75.14             488.53
# 3550        25.42           75.60       1017.39       77.63             438.24
# 3747        11.61           41.17       1019.57       58.82             476.81
# 4292        12.27           41.17       1019.41       58.10             475.13
# 4528        24.63           59.57       1010.45       85.36             440.67
# 5065         8.57           41.17       1020.18       72.47             484.20
# 5564        11.82           41.17       1019.50       55.74             475.61
# 5812        25.21           75.60       1017.19       69.84             445.84
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
## reseting the index after drop
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (9527, 5)

# %%
## Checking for missing values

# %%
df.isna().sum()
# Out:
# temperature          0
# exhaust_vacuum       0
# amb_pressure         0
# r_humidity           0
# energy_production    0
# dtype: int64

# %% [markdown]
# ## Outlier detection

# %%
for column in df.columns:
    plt.figure(figsize=(15, 3))
    sns.boxplot(x=df[column],color='red')
    plt.title('Boxplot of '+ column)
    plt.show()

# %% [markdown]
# ### r_humidity and Ambient pressure contains ouliers

# %% [markdown]
# ### treating outliers

# %%
def outler_detection(data,colname):
    q1 = data[colname].quantile(0.25)
    q3 = data[colname].quantile(0.75)
    iqr= q3 - q1

    lower = q1-(1.5*iqr)
    upper = q3+(1.5*iqr)

    return print("lower:",lower,"upper:",upper)

# %%
outler_detection(df,'amb_pressure')
# Out:
# lower: 996.9125 upper: 1029.3725

# %%
outler_detection(df,'r_humidity')
# Out:
# lower: 31.16250000000001 upper: 117.06249999999999

# %%
print(df[(df.r_humidity<31.16250000000001)])
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 30          33.94           74.67       1015.94       28.16             427.98
# 233         34.65           74.67       1016.03       26.67             427.69
# 400         35.01           74.67       1016.10       26.30             428.48
# 1154        34.30           74.67       1015.98       25.89             427.84
# 1254        19.78           44.71       1015.70       29.43             465.49
# 1814        19.31           44.71       1016.13       30.59             463.00
# 5600        29.85           68.24       1007.01       30.99             433.43
# 5664        33.83           67.90       1005.94       29.86             428.12
# 6035        34.18           67.90       1005.87       30.34             425.50
# 6201        19.32           44.71       1015.30       28.81             464.38
# 7267        18.76           44.71       1015.15       30.83             462.18
# ...

# %%
print(df[(df.r_humidity>117.06249999999999)])
# Out:
# Empty DataFrame
# Columns: [temperature, exhaust_vacuum, amb_pressure, r_humidity, energy_production]
# Index: []

# %%
df=df[(df.r_humidity>31.16250000000001)&(df.r_humidity<117.06249999999999)]

# %%
##treating amp pressure
print(df[(df.amb_pressure<996.9125 )])
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 962         16.03           41.23        996.35       82.04             464.67
# 2790        14.84           41.23        995.02       88.00             464.85
# 3392        18.15           41.23        993.82       61.21             456.32
# 3877        15.34           41.23        996.87       86.56             465.16
# 4194        10.67           42.02        996.55       99.94             472.65
# 4231        12.95           41.23        993.74       96.35             469.05
# 4777        13.83           41.23        993.31       93.94             466.20
# 5161        14.13           41.23        994.60       93.02             467.84
# 5283        11.01           42.02        995.24       98.62             473.96
# 5555        15.62           41.23        992.89       83.99             463.21
# 5879         3.26           41.31        996.32      100.00             489.38
# ...

# %%
print(df[(df.amb_pressure>1029.3725)])
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 38           9.95           41.82       1033.09       69.44             477.52
# 175          9.06           41.92       1029.90       90.88             473.37
# 315         14.46           42.86       1031.34       69.84             464.44
# 319         14.58           41.92       1030.42       61.96             462.69
# 385         14.20           42.86       1031.96       69.59             468.63
# ...           ...             ...           ...         ...                ...
# 9058         9.42           41.40       1030.38       87.80             472.99
# 9090         7.66           41.92       1031.96       82.48             485.11
# 9293         5.97           36.25       1029.65       86.74             487.03
# 9330        14.31           42.86       1031.14       69.60             465.36
# 9462        12.02           41.92       1030.10       84.45             465.82
#
# [75 rows x 5 columns]

# %%
df=df[(df.amb_pressure>996.9700000000001 )&(df.amb_pressure<1029.29)]

# %%
for column in df.columns:
    plt.figure(figsize=(15, 3))
    sns.boxplot(x=df[column],color='red')
    plt.title('Boxplot of '+ column)
    plt.show()

# %%
#dist plot for all the feature columns

plt.subplot(2, 2, 1)
sns.distplot(df['amb_pressure'])

plt.subplot(2, 2, 2)
sns.distplot(df['exhaust_vacuum'])

plt.subplot(2, 2, 3)
sns.distplot(df['r_humidity'])

plt.subplot(2, 2, 4)
sns.distplot(df['temperature'])

plt.tight_layout()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df):

    # Create a DataFrame to store the VIF values
    df = df.drop('energy_production', axis=1)
    vif_df = pd.DataFrame()
    vif_df["Feature"] = df.columns
    vif_df["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]

    return vif_df

# Calculate VIF
vif_result = calculate_vif(df)

# %%
# Display the VIF values
pd.DataFrame(vif_result)
# Out:
#           Feature        VIF
# 0     temperature  39.564574
# 1  exhaust_vacuum  74.907218
# 2    amb_pressure  67.387193
# 3      r_humidity  41.182292

# %% [markdown]
# - A VIF of 1 indicates that there’s no correlation between a given predictor (independent variable) and any other predictors. This predictor is perfectly okay, and there’s no multicollinearity.
# - A VIF between 1 and 5 is generally considered acceptable. It suggests moderate correlation, but it is not severe enough to warrant corrective measures.
# - A VIF above 5 (or sometimes above 10, depending on the context and the field of study) indicates high multicollinearity. This can be problematic, and you might want to consider dropping the variable from your model or using techniques to address multicollinearity.

# %% [markdown]
# ##  high multicollinearity between exhaust_vacuum and amb_pressure lets compair their rsquare value and check which one to select.

# %%
import statsmodels.formula.api as smf
AMB = smf.ols('energy_production~temperature+amb_pressure+r_humidity',data = df).fit()
AMB.rsquared, AMB.aic
# Out:
# (0.9197828982016918, 56338.632384890385)

# %%
ex_v = smf.ols('energy_production~temperature+exhaust_vacuum+r_humidity',data = df).fit()
ex_v.rsquared, ex_v.aic
# Out:
# (0.9273381339325983, 55406.904689435294)

# %%
df.head()
# Out:
#    temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0         9.59           38.56       1017.01       60.10             481.30
# 1        12.04           42.34       1019.72       94.67             465.36
# 2        13.87           45.08       1024.42       81.69             465.48
# 3        13.72           54.30       1017.89       79.08             467.05
# 4        15.14           49.64       1023.78       75.00             463.58

# %%
df['temperature_sqaure']=df.temperature**(1/2)

# %%
df.head()
# Out:
#    temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production  \
# 0         9.59           38.56       1017.01       60.10             481.30
# 1        12.04           42.34       1019.72       94.67             465.36
# 2        13.87           45.08       1024.42       81.69             465.48
# 3        13.72           54.30       1017.89       79.08             467.05
# 4        15.14           49.64       1023.78       75.00             463.58
#
#    temperature_sqaure
# 0            3.096773
# 1            3.469870
# 2            3.724245
# 3            3.704052
# 4            3.891015

# %%
##output_file_path = r'C:\project plant output\cleaned_data.csv'

#df.to_csv(output_file_path,index=False)

# %%
df_removed_temp=df.drop(columns=['temperature'])

# %%
df_removed_temp.head()
# Out:
#    exhaust_vacuum  amb_pressure  r_humidity  energy_production  \
# 0           38.56       1017.01       60.10             481.30
# 1           42.34       1019.72       94.67             465.36
# 2           45.08       1024.42       81.69             465.48
# 3           54.30       1017.89       79.08             467.05
# 4           49.64       1023.78       75.00             463.58
#
#    temperature_sqaure
# 0            3.096773
# 1            3.469870
# 2            3.724245
# 3            3.704052
# 4            3.891015

# %%
df_removed_temp.columns
# Out:
# Index(['exhaust_vacuum', 'amb_pressure', 'r_humidity', 'energy_production',
#        'temperature_sqaure'],
#       dtype='object')

# %% [markdown]
# ## train test split

# %%
x=df.iloc[:,[1, 2, 3, 5]]
x
# Out:
#       exhaust_vacuum  amb_pressure  r_humidity  temperature_sqaure
# 0              38.56       1017.01       60.10            3.096773
# 1              42.34       1019.72       94.67            3.469870
# 2              45.08       1024.42       81.69            3.724245
# 3              54.30       1017.89       79.08            3.704052
# 4              49.64       1023.78       75.00            3.891015
# ...              ...           ...         ...                 ...
# 9522           49.69       1005.53       81.82            4.135215
# 9523           65.34       1015.42       52.80            4.972927
# 9524           56.24       1005.19       56.24            5.517246
# 9525           66.05       1020.61       80.29            4.795832
# 9526           49.25       1020.86       63.67            4.213075
#
# [9419 rows x 4 columns]

# %%
X=x.drop(columns=['amb_pressure'])

# %%
y=df.iloc[:,-2]
y
# Out:
# 0       481.30
# 1       465.36
# 2       465.48
# 3       467.05
# 4       463.58
#          ...
# 9522    457.32
# 9523    446.92
# 9524    429.34
# 9525    421.57
# 9526    454.41
# Name: energy_production, Length: 9419, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import ExtraTreesRegressor
modelcheck=ExtraTreesRegressor()
modelcheck.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(modelcheck.feature_importances_)
# Out:
# [0.36387665 0.04120773 0.02652246 0.56839316]

# %%
feat_imp=pd.Series(modelcheck.feature_importances_,index=x.columns)
feat_imp.plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# #### from this we understood that we can either choose exhaust_vacuum or ambient_pressure for building our final model.here i'm choosing from this we understood that we can either choose exhaust_vacuum or relative_humidity for building our final model.here i'm choosing exhaust_vacuum because it shows more importance

# %% [markdown]
# ### we drop ambient_pressure column and we choose temperatue,exhaust_vacuum and relative_humidity features.

# %% [markdown]
# # **X AND Y**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#       exhaust_vacuum  amb_pressure  r_humidity  temperature_sqaure
# 7182           41.16       1021.26       73.87            3.754997
# 4532           54.20       1012.90       66.73            5.150728
# 4522           63.07       1010.75       45.26            5.283938
# 1062           66.49       1012.71       63.46            5.014978
# 1829           71.77       1006.59       77.94            5.218237
# ...              ...           ...         ...                 ...
# 5797           42.77       1019.61       81.82            3.813135
# 5246           43.13       1017.91       92.37            2.662705
# 5449           44.78       1011.15       77.34            3.508561
# 873            62.10       1019.94       76.41            4.464303
# 7350           43.69       1016.49       67.92            4.197618
#
# [6593 rows x 4 columns]

# %%
x
# Out:
#       exhaust_vacuum  amb_pressure  r_humidity  temperature_sqaure
# 0              38.56       1017.01       60.10            3.096773
# 1              42.34       1019.72       94.67            3.469870
# 2              45.08       1024.42       81.69            3.724245
# 3              54.30       1017.89       79.08            3.704052
# 4              49.64       1023.78       75.00            3.891015
# ...              ...           ...         ...                 ...
# 9522           49.69       1005.53       81.82            4.135215
# 9523           65.34       1015.42       52.80            4.972927
# 9524           56.24       1005.19       56.24            5.517246
# 9525           66.05       1020.61       80.29            4.795832
# 9526           49.25       1020.86       63.67            4.213075
#
# [9419 rows x 4 columns]

# %%
y
# Out:
# 0       481.30
# 1       465.36
# 2       465.48
# 3       467.05
# 4       463.58
#          ...
# 9522    457.32
# 9523    446.92
# 9524    429.34
# 9525    421.57
# 9526    454.41
# Name: energy_production, Length: 9419, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled1= scaler.fit_transform(x_train)
x_test_scaled1= scaler.transform(x_test)

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=x_train)
plt.title('before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=x_train_scaled1)
plt.title('after scaling')
# Out:
# Text(0.5, 1.0, 'after scaling')

# %% [markdown]
# # **MODELS**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Selecting relevant features X = energy[['temperature', 'exhaust_vacuum', 'amb_pressure', 'r_humidity']] y = energy['energy_production']

# Split the data into training and testing sets (70% train, 30% test)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
# Initialize a dictionary to store results
score = {}

# %%
# Linear Regression
linear_reg = LinearRegression()

# Train the model
linear_reg.fit(x_train, y_train)

# Make predictions
y_pred_linear = linear_reg.predict(x_test)

# Evaluate
mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)
mae_linear = mean_absolute_error(y_test, y_pred_linear)

# Store and display results
score['Linear Regression'] = {'MSE': mse_linear, 'R^2': r2_linear, 'MAE': mae_linear}
print("Linear Regression:")
print("Mean Squared Error (MSE):", mse_linear)
print("R-squared (R^2) Score:", r2_linear)
print("Mean Absolute Error (MAE):", mae_linear)
# Out:
# Linear Regression:
# Mean Squared Error (MSE): 19.98472952031669
# R-squared (R^2) Score: 0.9316554860769737
# Mean Absolute Error (MAE): 3.5525664234970775

# %%
# Linear Regression
linear_reg = LinearRegression()

# Train the model
linear_reg.fit(x_train_scaled1, y_train)

# Make predictions
y_pred_linear = linear_reg.predict(x_test_scaled1)

# Evaluate
mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)
mae_linear = mean_absolute_error(y_test, y_pred_linear)

# Store and display results
score['Linear Regression'] = {'MSE': mse_linear, 'R^2': r2_linear, 'MAE': mae_linear}
print("Linear Regression:")
print("Mean Squared Error (MSE):", mse_linear)
print("R-squared (R^2) Score:", r2_linear)
print("Mean Absolute Error (MAE):", mae_linear)
# Out:
# Linear Regression:
# Mean Squared Error (MSE): 19.984729520316694
# R-squared (R^2) Score: 0.9316554860769737
# Mean Absolute Error (MAE): 3.552566423497078

# %%
# Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_regressor.fit(x_train, y_train)

# Make predictions
y_pred_rf = rf_regressor.predict(x_test)

# Evaluate
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)

# Store and display results
score['Random Forest Regressor'] = {'MSE': mse_rf, 'R^2': r2_rf, 'MAE': mae_rf}
print("Random Forest Regressor:")
print("Mean Squared Error (MSE):", mse_rf)
print("R-squared (R^2) Score:", r2_rf)
print("Mean Absolute Error (MAE):", mae_rf)
# Out:
# Random Forest Regressor:
# Mean Squared Error (MSE): 11.720478610488342
# R-squared (R^2) Score: 0.9599178756577758
# Mean Absolute Error (MAE): 2.4582867657466396

# %%
# Gradient Boosting Regressor
gb_regressor = GradientBoostingRegressor(n_estimators=100, random_state=42)

# Train the model
gb_regressor.fit(x_train, y_train)

# Make predictions
y_pred_gb = gb_regressor.predict(x_test)

# Evaluate
mse_gb = mean_squared_error(y_test, y_pred_gb)
r2_gb = r2_score(y_test, y_pred_gb)
mae_gb = mean_absolute_error(y_test, y_pred_gb)

# Store and display results
score['Gradient Boosting Regressor'] = {'MSE': mse_gb, 'R^2': r2_gb, 'MAE': mae_gb}
print("Gradient Boosting Regressor:")
print("Mean Squared Error (MSE):", mse_gb)
print("R-squared (R^2) Score:", r2_gb)
print("Mean Absolute Error (MAE):", mae_gb)
# Out:
# Gradient Boosting Regressor:
# Mean Squared Error (MSE): 15.388761201296214
# R-squared (R^2) Score: 0.9473729477744041
# Mean Absolute Error (MAE): 2.989696580565076

# %%
# Support Vector Machine (SVR)
svr_regressor = SVR(kernel='rbf')

# Scale the data (required for SVR)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# Train the model
svr_regressor.fit(X_train_scaled, y_train)

# Make predictions
y_pred_svr = svr_regressor.predict(X_test_scaled)

# Evaluate
mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)
mae_svr = mean_absolute_error(y_test, y_pred_svr)

# Store and display results
score['SVR'] = {'MSE': mse_svr, 'R^2': r2_svr, 'MAE': mae_svr}
print("Support Vector Machine (SVR):")
print("Mean Squared Error (MSE):", mse_svr)
print("R-squared (R^2) Score:", r2_svr)
print("Mean Absolute Error (MAE):", mae_svr)
# Out:
# Support Vector Machine (SVR):
# Mean Squared Error (MSE): 18.33440289609154
# R-squared (R^2) Score: 0.9372993338374467
# Mean Absolute Error (MAE): 3.2638824434335914

# %%
from sklearn.linear_model import Ridge

# Ridge Regression
ridge_reg = Ridge(alpha=1.0)  # You can adjust the alpha parameter for regularization

# Train the model
ridge_reg.fit(x_train, y_train)

# Make predictions
y_pred_ridge = ridge_reg.predict(x_test)

# Evaluate
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)
mae_ridge = mean_absolute_error(y_test, y_pred_ridge)

# Store and display results
score['Ridge Regression'] = {'MSE': mse_ridge, 'R^2': r2_ridge, 'MAE': mae_ridge}
print("Ridge Regression:")
print("Mean Squared Error (MSE):", mse_ridge)
print("R-squared (R^2) Score:", r2_ridge)
print("Mean Absolute Error (MAE):", mae_ridge)
# Out:
# Ridge Regression:
# Mean Squared Error (MSE): 19.9820564909881
# R-squared (R^2) Score: 0.9316646274011022
# Mean Absolute Error (MAE): 3.5525671870390307

# %%
from sklearn.linear_model import Lasso

# Lasso Regression
lasso_reg = Lasso(alpha=1.0)  # You can adjust the alpha parameter for regularization

# Train the model
lasso_reg.fit(x_train, y_train)

# Make predictions
y_pred_lasso = lasso_reg.predict(x_test)

# Evaluate
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)
mae_lasso = mean_absolute_error(y_test, y_pred_lasso)

# Store and display results
score['Lasso Regression'] = {'MSE': mse_lasso, 'R^2': r2_lasso, 'MAE': mae_lasso}
print("Lasso Regression:")
print("Mean Squared Error (MSE):", mse_lasso)
print("R-squared (R^2) Score:", r2_lasso)
print("Mean Absolute Error (MAE):", mae_lasso)
# Out:
# Lasso Regression:
# Mean Squared Error (MSE): 25.26099065103721
# R-squared (R^2) Score: 0.9136115339712694
# Mean Absolute Error (MAE): 4.007006952062645

# %%
from sklearn.neighbors import KNeighborsRegressor

# KNN Regression
knn_reg = KNeighborsRegressor(n_neighbors=5)  # Adjust n_neighbors as needed

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# Train the model
knn_reg.fit(X_train_scaled, y_train)

# Make predictions
y_pred_knn = knn_reg.predict(X_test_scaled)

# Evaluate
mse_knn = mean_squared_error(y_test, y_pred_knn)
r2_knn = r2_score(y_test, y_pred_knn)
mae_knn = mean_absolute_error(y_test, y_pred_knn)

# Store and display results
score['KNN Regression'] = {'MSE': mse_knn, 'R^2': r2_knn, 'MAE': mae_knn}
print("K-Nearest Neighbors (KNN) Regression:")
print("Mean Squared Error (MSE):", mse_knn)
print("R-squared (R^2) Score:", r2_knn)
print("Mean Absolute Error (MAE):", mae_knn)
# Out:
# K-Nearest Neighbors (KNN) Regression:
# Mean Squared Error (MSE): 15.088726518046698
# R-squared (R^2) Score: 0.9483990174325343
# Mean Absolute Error (MAE): 2.813513800424627

# %%
import xgboost as xgb

# XGBoost Regression
xgb_reg = xgb.XGBRegressor(objective ='reg:squarederror', random_state=42)

# Train the model
xgb_reg.fit(x_train, y_train)

# Make predictions
y_pred_xgb = xgb_reg.predict(x_test)

# Evaluate
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)

# Store and display results
score['XGBoost Regression'] = {'MSE': mse_xgb, 'R^2': r2_xgb, 'MAE': mae_xgb}
print("XGBoost Regression:")
print("Mean Squared Error (MSE):", mse_xgb)
print("R-squared (R^2) Score:", r2_xgb)
print("Mean Absolute Error (MAE):", mae_xgb)
# Out:
# XGBoost Regression:
# Mean Squared Error (MSE): 10.82651392951365
# R-squared (R^2) Score: 0.9629750889927602
# Mean Absolute Error (MAE): 2.3594200342695335

# %%
from sklearn.neural_network import MLPRegressor

# MLP Regression
mlp_reg = MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', random_state=42)

# Train the model
mlp_reg.fit(x_train, y_train)

# Make predictions
y_pred_mlp = mlp_reg.predict(x_test)

# Evaluate
mse_mlp = mean_squared_error(y_test, y_pred_mlp)
r2_mlp = r2_score(y_test, y_pred_mlp)
mae_mlp = mean_absolute_error(y_test, y_pred_mlp)

# Store and display results
score['MLP Regression'] = {'MSE': mse_mlp, 'R^2': r2_mlp, 'MAE': mae_mlp}
print("Multi-layer Perceptron (MLP) Regression:")
print("Mean Squared Error (MSE):", mse_mlp)
print("R-squared (R^2) Score:", r2_mlp)
print("Mean Absolute Error (MAE):", mae_mlp)
# Out:
# Multi-layer Perceptron (MLP) Regression:
# Mean Squared Error (MSE): 29.01785849722277
# R-squared (R^2) Score: 0.90076365896953
# Mean Absolute Error (MAE): 4.26055024773839

# %%
from sklearn.tree import DecisionTreeRegressor

# Decision Tree Regression
dt_reg = DecisionTreeRegressor(random_state=42)

# Train the model
dt_reg.fit(x_train, y_train)

# Make predictions
y_pred_dt = dt_reg.predict(x_test)

# Evaluate
mse_dt = mean_squared_error(y_test, y_pred_dt)
r2_dt = r2_score(y_test, y_pred_dt)
mae_dt = mean_absolute_error(y_test, y_pred_dt)

# Store and display results
score['Decision Tree Regression'] = {'MSE': mse_dt, 'R^2': r2_dt, 'MAE': mae_dt}
print("Decision Tree Regression:")
print("Mean Squared Error (MSE):", mse_dt)
print("R-squared (R^2) Score:", r2_dt)
print("Mean Absolute Error (MAE):", mae_dt)
# Out:
# Decision Tree Regression:
# Mean Squared Error (MSE): 20.963911818825192
# R-squared (R^2) Score: 0.9283068423955287
# Mean Absolute Error (MAE): 3.2037721160651094

# %%
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDRegressor

# RBF Network with SGDRegressor
rbf_features = RBFSampler(gamma=1, random_state=42)
X_train_rbf = rbf_features.fit_transform(x_train)
X_test_rbf = rbf_features.transform(x_test)

rbf_reg = SGDRegressor(max_iter=1000, tol=1e-3, random_state=42)

# Train the model
rbf_reg.fit(X_train_rbf, y_train)

# Make predictions
y_pred_rbf = rbf_reg.predict(X_test_rbf)

# Evaluate
mse_rbf = mean_squared_error(y_test, y_pred_rbf)
r2_rbf = r2_score(y_test, y_pred_rbf)
mae_rbf = mean_absolute_error(y_test, y_pred_rbf)

# Store and display results
score['RBF Network Regression'] = {'MSE': mse_rbf, 'R^2': r2_rbf, 'MAE': mae_rbf}
print("Radial Basis Function (RBF) Network Regression:")
print("Mean Squared Error (MSE):", mse_rbf)
print("R-squared (R^2) Score:", r2_rbf)
print("Mean Absolute Error (MAE):", mae_rbf)
# Out:
# Radial Basis Function (RBF) Network Regression:
# Mean Squared Error (MSE): 292.9167748665474
# R-squared (R^2) Score: -0.0017275729352710378
# Mean Absolute Error (MAE): 14.79552699194521

# %%
score_primary=pd.DataFrame(score)
score_primary
# Out:
#      Linear Regression  Random Forest Regressor  Gradient Boosting Regressor  \
# MSE          19.984730                11.720479                    15.388761
# R^2           0.931655                 0.959918                     0.947373
# MAE           3.552566                 2.458287                     2.989697
#
#            SVR  Ridge Regression  Lasso Regression  KNN Regression  \
# MSE  18.334403         19.982056         25.260991       15.088727
# R^2   0.937299          0.931665          0.913612        0.948399
# MAE   3.263882          3.552567          4.007007        2.813514
#
#      XGBoost Regression  MLP Regression  Decision Tree Regression  \
# MSE           10.826514       29.017858                 20.963912
# R^2            0.962975        0.900764                  0.928307
# MAE            2.359420        4.260550                  3.203772
#
#      RBF Network Regression
# MSE              292.916775
# R^2               -0.001728
# MAE               14.795527

# %% [markdown]
# ## from the above trained models,selecting models which is given .94 and above r^2 value ;for further hyperparameter tuning
#
# ### models selected=Randomforestregressor,gradient boosting,KNeighborsRegressor and xgboost

# %% [markdown]
# ## **RANDOM FOREST**

# %%
results={}

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
random_gridrf = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
                }
print(random_gridrf)
# Out:
# {'n_estimators': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8]}

# %%
rf=RandomForestRegressor()
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_gridrf,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-870d158da55a> in <cell line: 5>()
#       3                                random_state=100,n_jobs=-1)
#       4 ### fit the randomized model
# ----> 5 rf_randomcv.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1766     def _run_search(self, evaluate_candidates):
# ...

# %%
rf_randomcv.best_params_

# %%
### best parameters from randomcv

# %% [markdown]
# {'n_estimators': 1366,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 230}
#
#
# {'n_estimators': 1577,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 1000}

# %%
best_random_grid=rf_randomcv.best_estimator_
best_random_grid

# %% [markdown]
# (max_depth=230, max_features='log2', n_estimators=1366)

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
y_pred_rf = best_random_grid.predict(x_test)

# Evaluate
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)

# Store and display results
results['Random Forest Regressor'] = {'MSE': mse_rf, 'R^2': r2_rf, 'MAE': mae_rf}
print("Random Forest Regressor:")
print("Mean Squared Error (MSE):", mse_rf)
print("R-squared (R^2) Score:", r2_rf)
print("Mean Absolute Error (MAE):", mae_rf)

# %% [markdown]
# Random Forest Regressor:
# Mean Squared Error (MSE): 10.863601823781337
# R-squared (R^2) Score: 0.9628482544462342
# Mean Absolute Error (MAE): 2.3584750497109797

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'],
                         rf_randomcv.best_params_['min_samples_leaf']+2,
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] - 2,
                          rf_randomcv.best_params_['min_samples_split'] - 1,
                          rf_randomcv.best_params_['min_samples_split'],
                          rf_randomcv.best_params_['min_samples_split'] +1,
                          rf_randomcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rf_randomcv.best_params_['n_estimators'] - 200, rf_randomcv.best_params_['n_estimators'] - 100,
                     rf_randomcv.best_params_['n_estimators'],
                     rf_randomcv.best_params_['n_estimators'] + 100, rf_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)

# %%
param_grid0={'max_depth': [230], 'max_features': ['log2'], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [0, 1, 2, 3, 4], 'n_estimators': [1166, 1266, 1366, 1466, 1566]}

# %%
#### Fit the grid_search to the data
rf=RandomForestRegressor()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid0,cv=5,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)

# %%
grid_search.best_params_

# %%
best_grid2=grid_search.best_estimator_
best_grid2

# %%
{'max_depth': 230,
 'max_features': 'log2',
 'min_samples_leaf': 1,
 'min_samples_split': 2,
 'n_estimators': 1266}

# %% [markdown]
# {'max_depth': 230,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1266}
#
#
#  {'max_depth': 230,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1566}

# %%
y_pred_rfg =best_grid2.predict(x_test)

# Evaluate
mse_rfg = mean_squared_error(y_test, y_pred_rfg)
r2_rfg = r2_score(y_test, y_pred_rfg)
mae_rfg = mean_absolute_error(y_test, y_pred_rfg)

# Store and display results
results['Random Forest Regressor grid'] = {'MSE': mse_rfg, 'R^2': r2_rfg, 'MAE': mae_rfg}
print("Random Forest Regressor grid:")
print("Mean Squared Error (MSE):", mse_rfg)
print("R-squared (R^2) Score:", r2_rfg)
print("Mean Absolute Error (MAE):", mae_rfg)

# %% [markdown]
# Random Forest Regressor grid:
# Mean Squared Error (MSE): 10.845324752076564
# R-squared (R^2) Score: 0.9629107590490775
# Mean Absolute Error (MAE): 2.3564183747160956

# %% [markdown]
# #**xg_boost**

# %% [markdown]
# ##best parameters of random forest regressor with .9628  r2 value
#
# {'max_depth': 230, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1266}

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

n_estimators= [100, 200, 300]
learning_rate= [0.05,0.01, 0.1, 0.2, 0.10, 0.15, 0.20, 0.25, 0.30 ]
max_depth=[ 3, 4, 5, 6, 8, 10, 12, 15]
min_child_weight= [ 1, 3, 5, 7 ]
gamma= [ 0.0, 0.1, 0.2 , 0.3, 0.4 ]
subsample= [0.8, 1.0,0.5]
colsample_bytree= [ 0.3, 0.4, 0.5 , 0.7 ,1.0]

random_gridx = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'min_child_weight':min_child_weight,
               'gamma': gamma,
               'subsample':subsample,
               'colsample_bytree':colsample_bytree
                               }
print(random_gridx)
# Out:
# {'n_estimators': [100, 200, 300], 'learning_rate': [0.05, 0.01, 0.1, 0.2, 0.1, 0.15, 0.2, 0.25, 0.3], 'max_depth': [3, 4, 5, 6, 8, 10, 12, 15], 'min_child_weight': [1, 3, 5, 7], 'gamma': [0.0, 0.1, 0.2, 0.3, 0.4], 'subsample': [0.8, 1.0, 0.5], 'colsample_bytree': [0.3, 0.4, 0.5, 0.7, 1.0]}

# %%
import xgboost as xgb
xgb_regressor = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
xgb_random=RandomizedSearchCV(estimator=xgb_regressor,param_distributions=random_gridx,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
xgb_random.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
# ...

# %%
xgb_random.best_params_
# Out:
# {'subsample': 0.8,
#  'n_estimators': 300,
#  'min_child_weight': 3,
#  'max_depth': 10,
#  'learning_rate': 0.05,
#  'gamma': 0.0,
#  'colsample_bytree': 1.0}

# %% [markdown]
# {'subsample': 0.8,
#  'n_estimators': 300,
#  'min_child_weight': 3,
#  'max_depth': 10,
#  'learning_rate': 0.05,
#  'gamma': 0.0,
#  'colsample_bytree': 1.0}

# %%
best_random_model=xgb_random.best_estimator_
best_random_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_xg = best_random_model.predict(x_test)

# Evaluate
mse_xg = mean_squared_error(y_test, y_pred_xg)
r2_xg = r2_score(y_test, y_pred_xg)
mae_xg = mean_absolute_error(y_test, y_pred_xg)

# Store and display results
results['xgboost Regressor'] = {'MSE': mse_xg, 'R^2': r2_xg, 'MAE': mae_xg}
print("xgboost Regressor:")
print("Mean Squared Error (MSE):", mse_xg)
print("R-squared (R^2) Score:", r2_xg)
print("Mean Absolute Error (MAE):", mae_xg)
# Out:
# xgboost Regressor:
# Mean Squared Error (MSE): 10.029977517413293
# R-squared (R^2) Score: 0.9656991135461898
# Mean Absolute Error (MAE): 2.2303469483631346

# %%
param_grid3 = {
    'max_depth': [xgb_random.best_params_['max_depth']],
    'min_child_weight': [xgb_random.best_params_['min_child_weight']],
    'learning_rate': [xgb_random.best_params_['learning_rate'],
                      xgb_random.best_params_['learning_rate'] + 0.05,
                      xgb_random.best_params_['learning_rate'] + 0.1],
    'subsample': [xgb_random.best_params_['subsample']],
    'gamma': [xgb_random.best_params_['gamma']],
    'colsample_bytree': [xgb_random.best_params_['colsample_bytree'] - 0.1,
                         xgb_random.best_params_['colsample_bytree'],
                         xgb_random.best_params_['colsample_bytree'] + 0.1],
    'n_estimators': [xgb_random.best_params_['n_estimators'] - 200,
                     xgb_random.best_params_['n_estimators'] - 100,
                     xgb_random.best_params_['n_estimators'],
                     xgb_random.best_params_['n_estimators'] + 100,
                     xgb_random.best_params_['n_estimators'] + 200]
}

print(param_grid3)
# Out:
# {'max_depth': [10], 'min_child_weight': [3], 'learning_rate': [0.05, 0.1, 0.15000000000000002], 'subsample': [0.8], 'gamma': [0.0], 'colsample_bytree': [0.9, 1.0, 1.1], 'n_estimators': [100, 200, 300, 400, 500]}

# %%
xgb_regressor1 = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
xgb_grid=GridSearchCV(estimator=xgb_regressor1,param_grid=param_grid3,cv=10,n_jobs=-1,verbose=2)
xgb_grid.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 45 candidates, totalling 450 fits
# GridSearchCV(cv=10,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None,...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
# ...

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'gamma': 0.0,
#  'learning_rate': 0.05,
#  'max_depth': 10,
#  'min_child_weight': 3,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %% [markdown]
# {'colsample_bytree': 1.0,
#  'gamma': 0.0,
#  'learning_rate': 0.05,
#  'max_depth': 10,
#  'min_child_weight': 3,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %%
xgb_grid.best_estimator_
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
best_gridmodel4=xgb_grid.best_estimator_

# %%
y_pred_xg1 = best_gridmodel4.predict(x_test)

# Evaluate
mse_xg1 = mean_squared_error(y_test, y_pred_xg1)
r2_xg1 = r2_score(y_test, y_pred_xg1)
mae_xg1 = mean_absolute_error(y_test, y_pred_xg1)

# Store and display results
results['xgboost Regressor grid'] = {'MSE': mse_xg1, 'R^2': r2_xg1, 'MAE': mae_xg1}
print("xgboost:")
print("Mean Squared Error (MSE):", mse_xg1)
print("R-squared (R^2) Score:", r2_xg1)
print("Mean Absolute Error (MAE):", mae_xg1)
# Out:
# xgboost:
# Mean Squared Error (MSE): 10.029977517413293
# R-squared (R^2) Score: 0.9656991135461898
# Mean Absolute Error (MAE): 2.2303469483631346

# %% [markdown]
# Random Forest Regressor:
# Mean Squared Error (MSE): 10.029977517413293
# R-squared (R^2) Score: 0.9656991135461898
# Mean Absolute Error (MAE): 2.2303469483631346

# %% [markdown]
# # **GradientBoostingRegressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

gb_regressor = GradientBoostingRegressor()

# %%
paramss_grid = {
    'n_estimators': [100, 200, 300,400,500],  # Number of boosting stages
    'learning_rate': [0.01, 0.05, 0.1, 0.5],  # Step size shrinkage
    'max_depth': [3, 4, 5],  # Maximum depth of the individual estimators
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required to be at a leaf node
}

# %%
grid_search = GridSearchCV(estimator=gb_regressor, param_grid=paramss_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.5],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=2)

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best score found: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
# Best score found:  0.9636815471533706

# %% [markdown]
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#
# Best score found:  0.9636815471533706

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
best_gb_regressor = grid_search.best_estimator_
y_pred = best_gb_regressor.predict(x_test)

mse_grad = mean_squared_error(y_test, y_pred)
r2_grad = r2_score(y_test, y_pred)
mae_grad = mean_absolute_error(y_test, y_pred)

# Store and display results
results['gradient Regressor grid'] = {'MSE': mse_grad, 'R^2': r2_grad, 'MAE': mae_grad}
print("gradient:")
print("Mean Squared Error (MSE):", mse_grad)
print("R-squared (R^2) Score:", r2_grad)
print("Mean Absolute Error (MAE):", mae_grad)
# Out:
# gradient:
# Mean Squared Error (MSE): 9.975736206519597
# R-squared (R^2) Score: 0.9658846099785436
# Mean Absolute Error (MAE): 2.247021875988333

# %% [markdown]
# gradient:
# Mean Squared Error (MSE): 9.975736206519597
# R-squared (R^2) Score: 0.9658846099785436
# Mean Absolute Error (MAE): 2.247021875988333

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

# %%
knn_regressor = KNeighborsRegressor()

# %%
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
}

# %%
grid_search = GridSearchCV(estimator=knn_regressor, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(x_train_scaled1, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              verbose=2)

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best score found: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'distance'}
# Best score found:  0.9490063988220534

# %%
best_knn_regressor = grid_search.best_estimator_
y_pred = best_knn_regressor.predict(x_test_scaled1)

mse_knn = mean_squared_error(y_test, y_pred)
r2_knn = r2_score(y_test, y_pred)
mae_knn = mean_absolute_error(y_test, y_pred)

# Store and display results
results['KNN Regressor grid'] = {'MSE': mse_knn, 'R^2': r2_knn, 'MAE': mae_knn}
print("KNN:")
print("Mean Squared Error (MSE):", mse_knn)
print("R-squared (R^2) Score:", r2_knn)
print("Mean Absolute Error (MAE):", mae_knn)
# Out:
# KNN:
# Mean Squared Error (MSE): 14.133261311467972
# R-squared (R^2) Score: 0.9516665525296494
# Mean Absolute Error (MAE): 2.6835678928334046

# %% [markdown]
# #**Final result**

# %%
result=pd.DataFrame(results)
result
# Out:
#      gradient Regressor grid  KNN Regressor grid  xgboost Regressor  \
# MSE                 9.975736           14.133261          10.029978
# R^2                 0.965885            0.951667           0.965699
# MAE                 2.247022            2.683568           2.230347
#
#      xgboost Regressor grid  Random Forest Regressor  \
# MSE               10.029978                10.875572
# R^2                0.965699                 0.962807
# MAE                2.230347                 2.360214
#
#      Random Forest Regressor grid
# MSE                     10.845325
# R^2                      0.962911
# MAE                      2.356418

# %%
output_file_path = r'C:\project plant output\results_data_df.csv'

#result.to_csv(output_file_path,index=False)

# %%
output_file_path = r'C:\project plant output\score_data_df.csv'

#score_primary.to_csv(output_file_path,index=False)

# %%
result
# Out:
#      gradient Regressor grid  KNN Regressor grid  xgboost Regressor  \
# MSE                 9.975736           14.133261          10.029978
# R^2                 0.965885            0.951667           0.965699
# MAE                 2.247022            2.683568           2.230347
#
#      xgboost Regressor grid  Random Forest Regressor  \
# MSE               10.029978                10.875572
# R^2                0.965699                 0.962807
# MAE                2.230347                 2.360214
#
#      Random Forest Regressor grid
# MSE                     10.845325
# R^2                      0.962911
# MAE                      2.356418

# %%
score_primary
# Out:
#      Linear Regression  Random Forest Regressor  Gradient Boosting Regressor  \
# MSE          19.984730                11.720479                    15.388761
# R^2           0.931655                 0.959918                     0.947373
# MAE           3.552566                 2.458287                     2.989697
#
#            SVR  Ridge Regression  Lasso Regression  KNN Regression  \
# MSE  18.334403         19.982056         25.260991       15.088727
# R^2   0.937299          0.931665          0.913612        0.948399
# MAE   3.263882          3.552567          4.007007        2.813514
#
#      XGBoost Regression  MLP Regression  Decision Tree Regression  \
# MSE           10.826514       29.017858                 20.963912
# R^2            0.962975        0.900764                  0.928307
# MAE            2.359420        4.260550                  3.203772
#
#      RBF Network Regression
# MSE              292.916775
# R^2               -0.001728
# MAE               14.795527

# %% [markdown]
# ## **trying some manual hyperparameter tuning**

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb_regressor = GradientBoostingRegressor()

# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
#(n_estimators=700, learning_rate=0.1, max_depth=6,min_samples_leaf=2,min_samples_split=2,random_state=42)
#(n_estimators=1230, learning_rate=0.1, max_depth=6,min_samples_leaf=2,min_samples_split=2,random_state=42)
model = GradientBoostingRegressor(n_estimators=1230, learning_rate=0.1, max_depth=6,min_samples_leaf=2,min_samples_split=2,random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=6, min_samples_leaf=2, n_estimators=1230,
#                           random_state=42)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

y_pred = model.predict(x_test)
mse_grad = mean_squared_error(y_test, y_pred)
r2_grad = r2_score(y_test, y_pred)
mae_grad = mean_absolute_error(y_test, y_pred)
print("gradient:")
print("Mean Squared Error (MSE):", mse_grad)
print("R-squared (R^2) Score:", r2_grad)
print("Mean Absolute Error (MAE):", mae_grad)
# Out:
# gradient:
# Mean Squared Error (MSE): 9.227297153301105
# R-squared (R^2) Score: 0.9684441494129516
# Mean Absolute Error (MAE): 2.14080234868904

# %%
x_train
# Out:
#       exhaust_vacuum  amb_pressure  r_humidity  temperature_sqaure
# 7182           41.16       1021.26       73.87            3.754997
# 4532           54.20       1012.90       66.73            5.150728
# 4522           63.07       1010.75       45.26            5.283938
# 1062           66.49       1012.71       63.46            5.014978
# 1829           71.77       1006.59       77.94            5.218237
# ...              ...           ...         ...                 ...
# 5797           42.77       1019.61       81.82            3.813135
# 5246           43.13       1017.91       92.37            2.662705
# 5449           44.78       1011.15       77.34            3.508561
# 873            62.10       1019.94       76.41            4.464303
# 7350           43.69       1016.49       67.92            4.197618
#
# [6593 rows x 4 columns]

# %%
import pickle

file=open('gradientboostingmodelpowerplant.pkl','wb')
pickle.dump(model,file)
